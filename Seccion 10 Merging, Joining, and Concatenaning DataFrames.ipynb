# %% [markdown]
# - [1.- Intro to Merging, Joining, and Concatenaning DataFrames](#1)
# - [2.- The pd.concat Method](#2)
# - [3.- Inner Joins](#3)
# - [4.- Outer Joins](#4)
# - [5.- Left Joins](#5)

# %%
import pandas as pd

# %% [markdown]
# # 1
# ### Intro to Merging, Joining, and Concatenaning DataFrames

# %%
week1 = pd.read_csv('./data/Restaurant - Week 1 Sales.csv')
week2 = pd.read_csv('./data/Restaurant - Week 2 Sales.csv')
customers = pd.read_csv('./data/Restaurant - Customers.csv')
foods = pd.read_csv("./data/Restaurant - Foods.csv")

# %%
customers.head()
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive
# 3   4     Steven     Evans    Male     Fatz               Registered Nurse
# 4   5       Judy  Morrison  Female  Demivee                Legal Assistant

# %%
foods.head()
# Out:
#    Food ID   Food Item  Price
# 0        1       Sushi   3.99
# 1        2     Burrito   9.99
# 2        3        Taco   2.99
# 3        4  Quesadilla   4.25
# 4        5       Pizza   2.49

# %% [markdown]
# # 2
# ### The pd.concat Method

# %%
week1.head()
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1
# 3          202        2
# 4          155        9

# %%
week2.head()
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10
# 3          189        5
# 4          267        3

# %%
pd.concat(objs = [week1,week2],ignore_index = True)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 495          783       10
# 496          556       10
# 497          547        9
# 498          252        9
# 499          249        6
#
# [500 rows x 2 columns]

# %%
week1.append(week2,ignore_index = True)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 495          783       10
# 496          556       10
# 497          547        9
# 498          252        9
# 499          249        6
#
# [500 rows x 2 columns]

# %%
sales = pd.concat([week1,week2], keys = ["Week 1","Week 2"])
sales.head()
# Out:
#           Customer ID  Food ID
# Week 1 0          537        9
#        1           97        4
#        2          658        1
#        3          202        2
#        4          155        9

# %%
sales.loc[("Week 1",240)]
# Out:
# Customer ID    945
# Food ID          5
# Name: (Week 1, 240), dtype: int64

# %% [markdown]
# # 3
# ### Inner Joins

# %%
week1.merge(week2, how = "inner",on = [ "Customer ID"])
# Out:
#     Customer ID  Food ID_x  Food ID_y
# 0           537          9          5
# 1           155          9          3
# 2           155          1          3
# 3           503          5          8
# 4           503          5          9
# ..          ...        ...        ...
# 57          945          5          4
# 58          343          3          5
# 59          343          3          2
# 60          343          3          7
# 61          621          9          6
#
# [62 rows x 3 columns]

# %%
week1[week1["Customer ID"] == 155]
# Out:
#     Customer ID  Food ID
# 4           155        9
# 17          155        1

# %%
week2[week2["Customer ID"] == 155]
# Out:
#      Customer ID  Food ID
# 208          155        3

# %%
week1.merge(week2, how = "inner",on =  "Customer ID",suffixes = ["- Week 1","- Week 2"])
# Out:
#     Customer ID  Food ID- Week 1  Food ID- Week 2
# 0           537                9                5
# 1           155                9                3
# 2           155                1                3
# 3           503                5                8
# 4           503                5                9
# ..          ...              ...              ...
# 57          945                5                4
# 58          343                3                5
# 59          343                3                2
# 60          343                3                7
# 61          621                9                6
#
# [62 rows x 3 columns]

# %%
week1.merge(week2, how = "inner",on = [ "Customer ID","Food ID"])
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5           21        4
# 6          922        1
# 7          578        5
# 8          578        5

# %%
week1[week1["Customer ID"] == 21]
# Out:
#      Customer ID  Food ID
# 101           21        4
# 212           21        4

# %%
week2[week2["Customer ID"] == 21]
# Out:
#     Customer ID  Food ID
# 30           21        4

# %% [markdown]
# # 4
# ### Outer Joins

# %%
week1.merge(week2, how = "outer",on = [ "Customer ID"],suffixes = ["- Week 1","- Week 2"])
# Out:
#      Customer ID  Food ID- Week 1  Food ID- Week 2
# 0            537              9.0              5.0
# 1             97              4.0              NaN
# 2            658              1.0              NaN
# 3            202              2.0              NaN
# 4            155              9.0              3.0
# ..           ...              ...              ...
# 449          855              NaN              4.0
# 450          559              NaN             10.0
# 451          276              NaN              4.0
# 452          556              NaN             10.0
# 453          252              NaN              9.0
#
# [454 rows x 3 columns]

# %%
merged = week1.merge(week2, how = "outer",on = [ "Customer ID"],suffixes = ["- Week 1","- Week 2"],indicator = True)

# %%
merged.head()
# Out:
#    Customer ID  Food ID- Week 1  Food ID- Week 2     _merge
# 0          537              9.0              5.0       both
# 1           97              4.0              NaN  left_only
# 2          658              1.0              NaN  left_only
# 3          202              2.0              NaN  left_only
# 4          155              9.0              3.0       both

# %%
merged('_merged').value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-c7dd8f47acf7> in <module>
# ----> 1 merged('_merged').value_counts()
#
# TypeError: 'DataFrame' object is not callable

# %% [markdown]
# # 5
# ### Left Joins
